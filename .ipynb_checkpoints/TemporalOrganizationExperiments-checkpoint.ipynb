# %%
using JuMP, Printf, Dates

include("src/lib/market_clearers/clear_market.jl")

test_name = @sprintf "compare%d" datetime2unix(now())
results_dir = "../DATA/$(test_name)"
mkdir(results_dir)
println(test_name)
result = ClearMarket.ClearMarketComparison("src/configs/experiments/compare_rolling_and_fixed.yaml",test_name)
# println(result)

println("done")
# Out:
# compare1777567052
# [36, 24, 24]
# Any[Dict{Symbol, Any}(:lookAheadDistance => 1, :clockTimeBegin => 0, :enforceRampRates => true, :optimizationWindow => 36, :name => "RollingHorizon", :timePeriodsPerDay => 24, :clearingInterval => 1)]
# Any[Dict{Symbol, Any}(:lookAheadDistance => 12, :clockTimeBegin => 12, :enforceRampRates => true, :optimizationWindow => 24, :name => "DayAhead", :timePeriodsPerDay => 24, :clearingInterval => 24), Dict{Symbol, Any}(:lookAheadDistance => 2, :clockTimeBegin => 22, :enforceRampRates => true, :optimizationWindow => 24, :name => "Intraday1", :timePeriodsPerDay => 24, :clearingInterval => 24)]
# RollingHorizon market at time: 0 looking ahead 1 with optimization window length 36
# OPTIMAL
# price: 97.2
# price: 97.2
# price: 100.0
# price: 120.0
# price: 100.0
# price: 120.0
# price: 120.0
# price: 120.0
# price: 97.2
# price: 97.2
# price: 97.2
# price: 120.0
# price: 120.0
# price: 120.0
# price: 120.0
# price: 120.0
# price: 120.0
# price: 97.2
# ...
